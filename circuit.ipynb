# %% [markdown]
# <a href="https://colab.research.google.com/github/smartrecycling2023/RS/blob/main/circuit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![circuit.png](data:image/png;base64,...)
